# %%
from pandas import read_csv
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import collections

# %%
def GetData2(fileName):
    return read_csv(fileName, header=0, parse_dates=[0], index_col=0)
series = GetData2('/Users/alh/Downloads/The BLACK Experience (School History Survey) (Responses) - Form Responses 1-2.csv')

# %%
type(series)
# Out:
# pandas.core.frame.DataFrame

# %%
series
# Out:
#                     You give Freedom Soul Media Education Initiatives (FSMEI) permission to use information collected in this survey for education/research purposes.   \
# Timestamp
# 2020-02-26 14:22:25                                                Yes
# 2020-02-26 15:14:13                                                Yes
# 2020-02-26 16:04:53                                                Yes
# 2020-02-26 17:29:27                                                Yes
# 2020-02-26 18:52:56                                                Yes
# 2020-02-26 23:51:17                                                Yes
# 2020-02-27 14:02:49                                                Yes
# 2020-02-28 19:54:39                                                Yes
# 2020-02-28 19:54:49                                                Yes
# 2020-03-02 13:21:20                                                Yes
# 2020-03-02 17:08:25                                                Yes
# ...

# %%
series['If so, what was the lesson?']
# Out:
# Timestamp
# 2020-02-26 14:22:25                                                  NaN
# 2020-02-26 15:14:13                                                  NaN
# 2020-02-26 16:04:53                                                  NaN
# 2020-02-26 17:29:27                                                  NaN
# 2020-02-26 18:52:56                                                  NaN
# 2020-02-26 23:51:17                                                  NaN
# 2020-02-27 14:02:49                                                  NaN
# 2020-02-28 19:54:39                                                  NaN
# 2020-02-28 19:54:49                                                  NaN
# 2020-03-02 13:21:20                                                  NaN
# 2020-03-02 17:08:25                                                  NaN
# 2020-03-02 17:19:14                                                  NaN
# 2020-03-02 23:15:04                                                  NaN
# ...

# %%
year=series.groupby('In what decade did you finish school? (K-12th grade)')

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
year.describe()
# Out:
#                                                    1. Did your school have a majority black population of students/teachers?  \
#                                                                                                                        count
# In what decade did you finish school? (K-12th g...
# 1950s                                                                                               0
# 1960s                                                                                               5
# 1970s                                                                                               9
# 1980s                                                                                               9
# 1990s                                                                                              34
# 2000s                                                                                              47
# ...

# %%
area=series.groupby('I attended school (majority of your schooling)')

# %%
area.describe()
# Out:
#                                                1. Did your school have a majority black population of students/teachers?  \
#                                                                                                                    count
# I attended school (majority of your schooling)
# In the Mid West                                                                                10
# In the South                                                                                   13
# On the East Coast                                                                              30
# On the West Coast                                                                              76
#
#                                                                  \
#                                                unique  top freq
# I attended school (majority of your schooling)
# In the Mid West                                     2   No    7
# ...

# %%
area['']

# %%
culture=series.groupby('My background is')

# %%
culture.describe()
# Out:
#                                                    1. Did your school have a majority black population of students/teachers?  \
#                                                                                                                        count
# My background is
# African-American/Black                                                                            112
# African/Black                                                                                       0
# African/Black (you and/or parents born on the A...                                                  5
# Black                                                                                               0
# Caribbean/Black (you and/or parents born in the...                                                  4
# Mixed                                                                                               8
#
#                                                                      \
# ...

# %%
#question 12
q12 = collections.Counter()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-144-bd6eed8c34a6> in <module>
#       1 #question 12
#       2 q12 = collections.Counter()
# ----> 3 with series as input_file:
#       4     for row in csv.reader(input_file['12. Would you have liked to have classes, programs, books and curriculum that allowed you to learn more about Black history and culture?'], delimiter=';'):
#       5         q12[row[1]] += 1
#
# AttributeError: __exit__
